# %% [markdown]
# # Derivation
# ## Potential
# $$U(r)=4\epsilon \left[\left(\frac{\sigma}{r}\right)^{12}-\left(\frac{\sigma}{r}\right)^6\right]$$
# ## Force
# $$F(r)=-\frac{dU}{dr}$$
# $$F(r)=\epsilon\left[48\frac{\sigma^{12}}{r^{13}}-24\frac{\sigma^6}{r^7}\right]=\frac{24\epsilon}{r}\left[2\left(\frac{\sigma}{r}\right)^{12}-\left(\frac{\sigma}{r}\right)^6\right]$$
# # Reduced forms
# ## Potential
# $$r^*=\frac{r}{\sigma}$$
# $$U(r^*)=4\epsilon\left[\left(\frac{1}{r^*}\right)^{12}-\left(\frac{1}{r^*}\right)^6\right]$$
# $$U^*=\frac{U}{\epsilon}$$
# $$U^*(r^*)=4\left[\left(\frac{1}{r^*}\right)^{12}-\left(\frac{1}{r^*}\right)^6\right]$$
# ## Force
# $$F^*(r^*)=-\frac{dU^*}{dr^*}=\frac{24}{r^*}\left[2\left(\frac{1}{r}\right)^{12}-\left(\frac{1}{r^*}\right)^6\right]$$

# %% [markdown]
# # Boundary conditions
# Periodic boundary conditions: particles leaving one side of the box, reenter on the opposite side.
# $$\Delta x_{ij}:=\Delta x_{ij}-L \times \text{round}\left(\frac{\Delta x_{ij}}{L}\right)$$
# where $\Delta x_{ij}$ is the distance between two particles, and $L$ is the lenght of the box (in this case all in one dimension).
#
# This ensures that the distance used in the calculations is always to the nearest periodic image of the particle, never the raw coordinate.

# %%
import random
import matplotlib.pyplot as plt
L=10
#Force calculation
i=round(random.uniform(0, L), 2)
j=round(random.uniform(0, L), 2)
x_ij=i-j
x_ij=x_ij-L*round(x_ij/L)
r_star=abs(x_ij)
F_star=24/r_star*(2*(1/r_star)**12-(1/r_star)**6)
if r_star >=2.5:
    F_star=0
#Plotting
x=[i, j]
y=[0, 0]
plt.scatter(x, y)
plt.axvline(0, color='black')
plt.axvline(L, color='black')
plt.ylim(-0.1, 1)
print("F* = "+ str(F_star))
print("r* = "+ str(r_star))
# Out:
# F* = 3.6457308979750587
# r* = 1.08
